# %% [markdown]
# # COVID19 Impact Analysis

# %% [markdown]
# ## Description
# -- This project is regarding COVID19 IMPACT ANALYSYS
#
# -- The requred tool to develop this project are :
#
#     a. Dash - framework for building data visualization interfaces
#
#     b. Flask - Web server functionalities
#
#     c. React.js - render the user interfaces of web pages
#
#     d. plotly.js - Generates charts that can used in applications
#
#     e. Basic HTML, CSS, BOOTSTRAP
#
#     f. pycharm

# %%
import numpy as np
import pandas as pd

# %%
patients=pd.read_csv('state_wise_daily.csv')

# %%
patients['Status'].value_counts()
# Out:
# Status
# Confirmed    597
# Recovered    597
# Deceased     597
# Name: count, dtype: int64

# %%
#calculating for CARDS
total=patients.shape[0]

# %%
#here we have done masking (Patients inside patients)
active= patients[patients['Status']=='Confirmed'].shape[0]
recovered= patients[patients['Status']=='Recovered'].shape[0]
deaths= patients[patients['Status']=='Deceased'].shape[0]

# %%
patients.head(20)
# Out:
#          Date    Date_YMD     Status  Total  Hospitalized  Recovered  \
# 0   14-Mar-20  14-03-2020  Confirmed     81            12        120
# 1   14-Mar-20  14-03-2020  Recovered      9            25          5
# 2   14-Mar-20  14-03-2020   Deceased      2            85         10
# 3   15-Mar-20  15-03-2020  Confirmed     27            89         15
# 4   15-Mar-20  15-03-2020  Recovered      4            10          5
# 5   15-Mar-20  15-03-2020   Deceased      0            15          8
# 6   16-Mar-20  16-03-2020  Confirmed     15             1         14
# 7   16-Mar-20  16-03-2020  Recovered      1             0         56
# 8   16-Mar-20  16-03-2020   Deceased      0            11         84
# 9   17-Mar-20  17-03-2020  Confirmed     11             1         12
# 10  17-Mar-20  17-03-2020  Recovered      1             1        156
# 11  17-Mar-20  17-03-2020   Deceased      1            37        214
# 12  18-Mar-20  18-03-2020  Confirmed     37            25         17
# ...

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1791 entries, 0 to 1790
# Data columns (total 43 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1791 non-null   object
#  1   Date_YMD      1791 non-null   object
#  2   Status        1791 non-null   object
#  3   Total         1791 non-null   int64
#  4   Hospitalized  1791 non-null   int64
#  5   Recovered     1791 non-null   int64
#  6   Deceased      1791 non-null   int64
#  7   Mask          1791 non-null   int64
#  8   Sanitizer     1791 non-null   int64
#  9   Oxygen        1791 non-null   int64
#  10  Red Zone      1791 non-null   int64
#  11  Blue Zone     1791 non-null   int64
#  12  Green Zone    1791 non-null   int64
#  13  Orange Zone   1791 non-null   int64
#  14  GA            1791 non-null   int64
#  15  GJ            1791 non-null   int64
#  16  HR            1791 non-null   int64
#  17  HP            1791 non-null   int64
# ...
